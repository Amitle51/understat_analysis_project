# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitle51/understat_analysis_project/blob/main/understat_analysis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Understat Football Match Analysis

# %% [markdown]
# ## Objectives
#
# In this analysis of Understat football match data, the goals are to:
#
# *TBC*

# %% [markdown]
# ## Data Loading and Description

# %%
import pandas as pd
df = pd.read_csv('/content/understat_per_game.csv')

# %%
print("Missing Values:\n", df.isnull().sum())

# %%
print("Duplicate Rows:", df.duplicated().sum())

# %%
print(df.dtypes)

# %%
df.describe()

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Correlations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_df = df.select_dtypes(include=['float64', 'int64'])
# Calculate the correlation matrix for numerical variables only
corr_matrix = numerical_df.corr()

# Plot the heatmap
plt.figure(figsize=(15, 12))  # Increase the figure size
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1, annot_kws={"size": 8})  # Adjust font size
plt.title("Correlation Matrix of Numerical Variables")
plt.show()
